# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics as st
j=0
i=0
temp=[]
filename = "C:\\Users\\USER F\\Desktop\\419\\2 курс\\Вычислительные методы\\4\\var09_z1.bin"  
data = np.fromfile(filename, dtype=np.int16)
print(data[:20])
time=np.arange(len(data))/1000.0

plt.figure(figsize=(12, 6))
plt.plot(time,data)
plt.grid()
plt.show()

step=10000
datam=[]
for i in range(len(data)):
    if len(data)-i<=9999:
        datam.append(0)
    else:
        datam.append(np.mean(data[i:i+step-1]))
        temp.clear()
plt.figure(figsize=(12, 6))
plt.plot(time,datam)
plt.xlim(0, 1750)
plt.ylim(125, 225)
plt.xticks(np.arange(0, 1750, step=100))
plt.grid()
plt.show()
# Out:
# [280 248 170 240 286 224 278 228 200 177 222 201 124 247 132 136 218 244
#  178 334]
